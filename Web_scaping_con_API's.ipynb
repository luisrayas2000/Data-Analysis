# %% [markdown]
# <a href="https://colab.research.google.com/github/luisrayas2000/Data-Analysis/blob/main/Web_scaping_con_API's.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
url_base = 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao'

# %%
import requests

# %%
r = requests.get(url_base)

# %%
r.status_code
# Out:
# 401

# %%
r.json()
# Out:
# {'error': {'status': 401, 'message': 'No token provided'}}

# %%
token_url = 'https://accounts.spotify.com/api/token'

# %%
params={'grant_type': 'client_credentials'}

# %%
headers = {'Authorization' : '' }

# %%
r=requests.post(token_url,data=params,headers=headers)

# %%
r.status_code
# Out:
# 400

# %%
r.json()
# Out:
# {'error': 'invalid_client'}

# %%
header = {'Authorization' : 'Bearer {}'.format(token)}

# %%
r = requests.get(url_base,headers =header )

# %%
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#  'followers': {'href': None, 'total': 8415711},
#  'genres': ['hard rock', 'metal', 'nwobhm', 'rock'],
#  'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#  'id': '6mdiAmATAx73kdxrNrnlao',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab6761610000e5eb6456e7b9c9215b3b09f4be57',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/ab676161000051746456e7b9c9215b3b09f4be57',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/ab6761610000f1786456e7b9c9215b3b09f4be57',
#    'width': 160}],
#  'name': 'Iron Maiden',
#  'popularity': 71,
#  'type': 'artist',
#  'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}

# %%
url_busqueda = 'https://api.spotify.com/v1/search'

# %%
search_params = {'q':"Iron+Maiden", 'type':'artist', 'market' : 'AR'}

# %%
busqueda = requests.get(url_busqueda,headers=header,params=search_params)

# %%
busqueda.status_code
# Out:
# 200

# %%
busqueda.json()
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=Iron%2BMaiden&type=artist&market=AR&offset=0&limit=20',
#   'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#     'followers': {'href': None, 'total': 8415711},
#     'genres': ['hard rock', 'metal', 'nwobhm', 'rock'],
#     'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#     'id': '6mdiAmATAx73kdxrNrnlao',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb6456e7b9c9215b3b09f4be57',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab676161000051746456e7b9c9215b3b09f4be57',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f1786456e7b9c9215b3b09f4be57',
#       'width': 160}],
#     'name': 'Iron Maiden',
#     'popularity': 71,
#     'type': 'artist',
#     'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'},
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame(busqueda.json()['artists']['items'])
df.head()
# Out:
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/artist/6...
# 1  {'spotify': 'https://open.spotify.com/artist/7...
# 2  {'spotify': 'https://open.spotify.com/artist/2...
# 3  {'spotify': 'https://open.spotify.com/artist/6...
# 4  {'spotify': 'https://open.spotify.com/artist/0...
#
#                           followers                            genres  \
# 0  {'href': None, 'total': 8415711}  [hard rock, metal, nwobhm, rock]
# 1     {'href': None, 'total': 1316}                                []
# 2     {'href': None, 'total': 3535}                                []
# 3     {'href': None, 'total': 5648}                                []
# 4     {'href': None, 'total': 1640}                                []
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/artists/6mdiAmATAx7...  6mdiAmATAx73kdxrNrnlao
# ...

# %%
df.sort_values(by='popularity',ascending=False).iloc[0]['id']
# Out:
# '6mdiAmATAx73kdxrNrnlao'

# %%
import base64

# %%
def get_token(client_id, client_secret):
  encoded = base64.b64encode(bytes(client_id+':'+client_secret,'utf-8'))
  params = {'grant_type': 'client_credentials'}
  header = {'Authorization':'Basic '+ str(encoded, 'utf-8')}
  r= requests.post('https://accounts.spotify.com/api/token', headers= header,data=params)
  if r.status_code != 200:
    print(header)
    print(r.status_code)
    print('Error en la request.', r.json())
    return None
  print('Token válido por {} segundos.'.format(r.json()['expires_in']))
  return r.json()['access_token']

# %%
client_id = 'client_id'
client_secret = 'client_secret'

# %%
token = get_token(client_id, client_secret)
# Out:
# {'Authorization': 'Basic Y2xpZW50X2lkOmNsaWVudF9zZWNyZXQ='}
# 400
# Error en la request. {'error': 'invalid_client', 'error_description': 'Invalid client'}

# %%
token

# %%
header = {'Authorization': 'Bearer {}'.format(token)}

# %%
ep_albums = 'artists/{id}/albums'

# %%
url_base
# Out:
# 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao'

# %%
params = {'country' : 'AR'}
url_albums= 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao/albums'

# %%
albums_im = requests.get('https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao/albums', headers= header, params = params)

# %%
albums_im.status_code
# Out:
# 200

# %%
albums_im.json()['items']
# Out:
# [{'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#     'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#     'id': '6mdiAmATAx73kdxrNrnlao',
#     'name': 'Iron Maiden',
#     'type': 'artist',
#     'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/3TymcPWXqsCRA5oSL0TkPU'},
#   'href': 'https://api.spotify.com/v1/albums/3TymcPWXqsCRA5oSL0TkPU',
#   'id': '3TymcPWXqsCRA5oSL0TkPU',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2739dded020fbe39dc9c3d3122f',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e029dded020fbe39dc9c3d3122f',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048519dded020fbe39dc9c3d3122f',
#     'width': 64}],
#   'is_playable': True,
# ...

# %%
def get_album_json(album_id):
    header = {"Authorization": "Bearer {}".format(token)}
    url_base = 'https://api.spotify.com/v1'
    album = requests.get(url_base+'/albums/'+album_id, headers=header)
    if album.status_code == 200:
        return album.json()
    else:
        print(f"Error en la requests: {album.status_code}")

get_album_json('2rVdAYBUuEnciOvQRrn4YL')
# Out:
# {'album_type': 'album',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#    'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#    'id': '6mdiAmATAx73kdxrNrnlao',
#    'name': 'Iron Maiden',
#    'type': 'artist',
#    'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#  'available_markets': ['AD',
#   'AE',
#   'AG',
#   'AL',
#   'AM',
#   'AO',
#   'AR',
#   'AT',
#   'AU',
#   'AZ',
#   'BA',
#   'BB',
#   'BD',
#   'BE',
#   'BF',
#   'BG',
#   'BH',
#   'BI',
#   'BJ',
#   'BN',
#   'BO',
#   'BR',
#   'BS',
#   'BT',
#   'BW',
#   'BY',
#   'BZ',
#   'CA',
#   'CD',
#   'CG',
#   'CH',
#   'CI',
#   'CL',
#   'CM',
#   'CO',
#   'CR',
#   'CV',
#   'CW',
#   'CY',
#   'CZ',
#   'DE',
#   'DJ',
#   'DK',
#   'DM',
#   'DO',
#   'DZ',
#   'EC',
#   'EE',
#   'EG',
#   'ES',
#   'FI',
#   'FJ',
#   'FM',
#   'FR',
#   'GA',
#   'GB',
#   'GD',
#   'GE',
#   'GH',
#   'GM',
#   'GN',
#   'GQ',
#   'GR',
# ...

# %%
url_albums
# Out:
# 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao/albums'

# %%
from requests.api import request
def obtener_discografia(artist_id, token, return_name= False, page_limit=50, country= None):
  url= f'https://api.spotify.com/v1/artists/{artist_id}/albums'
  header = {'Authorization' : f'Bearer {token}'}
  params = {'limit': page_limit,
            'offset':0,
            'country': country}
  lista = []
  r = requests.get(url, params = params, headers=header)
  if r.status_code != 200:
    print('Error en la request', r.json())
    return None
  if return_name:
    lista += [(item['id'], item['name']) for item in r.json()['items']]
  else:
    lista += [item['id']  for item in r.json()['items']]
  while r.json()['next']:
    r = requests.get(r.json(), headers= header)
    if return_name:
       if return_name:
        lista += [(item['id'], item['name']) for item in r.json()['items']]
    else:
      lista += [item['id']  for item in r.json()['items']]
  return lista

# %%
def obtener_tracks(album_id, token, return_name= False, page_limit=50, market= None):
  url= f'https://api.spotify.com/v1/albums/{album_id}/tracks'
  header = {'Authorization' : f'Bearer {token}'}
  params = {'limit': page_limit,
            'offset':0,
            'market': market}
  lista = []
  r = requests.get(url, params = params, headers=header)
  if r.status_code != 200:
    print('Error en la request', r.json())
    return None
  if return_name:
    lista += [(item['id'], item['name']) for item in r.json()['items']]
  else:
    lista += [item['id']  for item in r.json()['items']]
  while r.json()['next']:
    r = requests.get(r.json(), headers= header)
    if return_name:
       if return_name:
        lista += [(item['id'], item['name']) for item in r.json()['items']]
    else:
      lista += [item['id']  for item in r.json()['items']]
  return lista

# %%
id_im='6mdiAmATAx73kdxrNrnlao'

# %%
obtener_discografia(id_im, token, return_name=True,country='AR')
# Out:
# [('3TymcPWXqsCRA5oSL0TkPU', 'Senjutsu'),
#  ('6IVkf5av5jnraZpLPszoZR',
#   'Nights of the Dead, Legacy of the Beast: Live in Mexico City'),
#  ('3oFAX7PeOFbZnKiPmpUPv4', 'The Book of Souls: Live Chapter'),
#  ('4vSfHrq6XxVyMcJ6PguFR2', 'The Book of Souls'),
#  ('44myoe2TKVeLrIhfcN7xVK', "Maiden England '88 (2013 Remaster)"),
#  ('3LymDdEISKszJqeN2z9DBI', 'En Vivo!'),
#  ('5YAfxU5OZKqAvE1GZPRQYY', 'The Final Frontier (2015 Remaster)'),
#  ('3yTneaS0Z3xsAmCafaYjPw', 'Flight 666: The Original Soundtrack'),
#  ('1gdB9kn59KSAVG5VQcjdHi', 'A Matter of Life and Death (2015 Remaster)'),
#  ('2rVdAYBUuEnciOvQRrn4YL', 'Death on the Road'),
#  ('2Y8x0EEu7il0K2gCQIqVRh', 'Dance of Death (2015 Remaster)'),
#  ('1U3qu4gDfohAqFrmpLT11l', 'Beast Over Hammersmith (Live)'),
#  ('6LVjt0qej8oy3dAQQn98EW', 'BBC Archives (Live)'),
#  ('4SiZSq9igWhpJoMzjxE1xE', 'Rock in Rio (Live)'),
#  ('1hDF0QPIHVTnSJtxyQVguB', 'Brave New World (2015 Remaster)'),
# ...

# %%
obtener_tracks('2rVdAYBUuEnciOvQRrn4YL', token , return_name=True, market='AR')
# Out:
# [('2lYcnaVU0N37mdkHiKab7x', 'Wildest Dreams - Live In Dortmund'),
#  ('2btlhJSWESErc9fEFL5kGa', 'Wrathchild - Live In Dortmund'),
#  ('4RPnagR1LxnYExpeO1Yyj4', 'Can I Play With Madness - Live In Dortmund'),
#  ('1epMwPp7sGFyAIoiMIfyqb', 'The Trooper - Live 2003'),
#  ('28EkqX5zV5OlvJmkEd6gjP', 'Dance Of Death - Live In Dortmund'),
#  ('1470c6ZncysDG0f31O9JED', 'Rainmaker - Live In Dortmund'),
#  ('69RhfNvA7zcw0vR2dZaAHu', 'Brave New World - Live In Dortmund'),
#  ('5wcYco8Da7NTlaBIwsuBD3', 'Paschendale - Live In Dortmund'),
#  ('16bax1DtlF84DwReJhehSh', 'Lord Of The Flies - Live In Dortmund'),
#  ('6KueDW1pZ26JrwUWiS1sql', 'No More Lies - Live In Dortmund'),
#  ('6JLDXUBGMV76n2JXRUr3IC', 'Hallowed Be Thy Name - Live In Dortmund'),
#  ('6xyWFGqa1o3LqUPDiOwQCe', 'Fear Of The Dark - Live In Dortmund'),
#  ('38baZ5coiqucgfkMOS4SeM', 'Iron Maiden - Live In Dortmund'),
#  ('3jAWZHhkcIktHuDa7Lw8MD', 'Journeyman - Live In Dortmund'),
# ...

# %%
for album in obtener_discografia(id_im, token, return_name=True,country='AR'):
  print(album[1])
# Out:
# Senjutsu
# Nights of the Dead, Legacy of the Beast: Live in Mexico City
# The Book of Souls: Live Chapter
# The Book of Souls
# Maiden England '88 (2013 Remaster)
# En Vivo!
# The Final Frontier (2015 Remaster)
# Flight 666: The Original Soundtrack
# A Matter of Life and Death (2015 Remaster)
# Death on the Road
# Dance of Death (2015 Remaster)
# Beast Over Hammersmith (Live)
# BBC Archives (Live)
# Rock in Rio (Live)
# Brave New World (2015 Remaster)
# Virtual XI (2015 Remaster)
# The X Factor (2015 Remaster)
# A Real Live Dead One (Live; 1998 Remaster)
# Live at Donington (1998 Remaster)
# Fear of the Dark (2015 Remaster)
# No Prayer for the Dying (2015 Remaster)
# Seventh Son of a Seventh Son (2015 Remaster)
# Somewhere in Time (2015 Remaster)
# Live After Death (1998 Remaster)
# Powerslave (2015 Remaster)
# Piece of Mind (2015 Remaster)
# The Number of the Beast (2015 Remaster)
# Killers (2015 Remaster)
# Iron Maiden (2015 Remaster)
# Stratego
# The Writing On The Wall
# ...

# %%
preview_url = 'https://p.scdn.co/mp3-preview/04a7c6ed90759647969ef3eeb0ce80628c64a8de?cid=8954465f2ff54e1f8f31d717fef3ac9b'

# %%
preview = requests.get(preview_url)
preview
# Out:
# <Response [200]>

# %%
import IPython.display as ipd

# %%
preview.content

# %%
ipd.Audio(preview.content)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
